# %% [markdown]
# # Comparing Peak WSE for historic events in Jacksonville
#
# ### Using the Coastal Hazard System (CHS) [https://chs.erdc.dren.mil/] for select points in Jacksonville, FL
# ### Using data for CHS-SA_TH_SimB1HT_ADCIRC01_Peaks
#
# CHS-SA | Phase II of CHS-SACS - North Carolina to South Florida
# TH | Tropical Histoirical Storms
# SimB1HT | Base plus 1 historical tide; No sea level change
# ADCIRC01 | ADCIRC model
# Post0 | No Post Processing

# %% [markdown]
# # The following map shows the locations of the points downloaded from CHS in this analysis.

# %%
import folium
import json
import os
# Show ADCIRC points on map using folium and a geojson
geojson_fn = "CHS ADCIRC Test Points.geojson" 
m = folium.Map(location=[30.3322, -81.6557], tiles="CartoDB Positron", zoom_start=10)

tooltip = folium.GeoJsonTooltip(
    fields=["Point"],
    aliases=["ADCIRC Point"],
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

folium.GeoJson(
    geojson_fn,
    tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec9964266ee8adad9f57d4423014eaa8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#         background-color: #F0EFEF;
#         border: 2px solid black;
#         border-radius: 3px;
#         box-shadow: 3px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec9964266ee8adad9f57d4423014eaa8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec9964266ee8adad9f57d4423014eaa8 = L.map(
#                 &quot;map_ec9964266ee8adad9f57d4423014eaa8&quot;,
#                 {
#                     center: [30.3322, -81.6557],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_836a2b2b07dde051b6b43a9e61722b5c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec9964266ee8adad9f57d4423014eaa8);
#
#
#
#         function geo_json_bc0f907b70c5344a1a04a6864ac64fd1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bc0f907b70c5344a1a04a6864ac64fd1 = L.geoJson(null, {
#                 onEachFeature: geo_json_bc0f907b70c5344a1a04a6864ac64fd1_onEachFeature,
#
#         });
#
#         function geo_json_bc0f907b70c5344a1a04a6864ac64fd1_add (data) {
#             geo_json_bc0f907b70c5344a1a04a6864ac64fd1
#                 .addData(data)
#                 .addTo(map_ec9964266ee8adad9f57d4423014eaa8);
#         }
#             geo_json_bc0f907b70c5344a1a04a6864ac64fd1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.435, 30.523], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17393}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.411, 30.46], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17502}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.397, 30.364], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17808}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.3858, 30.2703], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 18090}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.465, 30.126], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 18525}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.494, 30.525], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17386}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.505, 30.245], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 18172}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.6171, 30.1587], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 18413}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.613, 30.365], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17804}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.624, 30.538], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17359}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.796, 30.47], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17491}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.783, 30.358], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 17824}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.7811, 30.213], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Point&quot;: 18274}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&qu

# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
import os
import glob

# Get the list of ADCIRC points from the geojson
with open(geojson_fn) as f:
    data = json.load(f)
    points = [feature["properties"]["Point"] for feature in data["features"]]

# %%
# Get the list of historical storms from the CHS data
# for each point, open the h5 file and get the list of storms.  Add to a list of storms and remove duplicates.
storms = []
for point in points:
    #  example hdf filename: "CHS-SA_TH_SimB1HT_ADCIRC01_Peaks\CHS-SA_TH_SimB1HT_Post0_SP17359_ADCIRC01_Peaks.h5"
    h5_fn = f"CHS-SA_TH_SimB1HT_ADCIRC01_Peaks/CHS-SA_TH_SimB1HT_Post0_SP{point}_ADCIRC01_Peaks.h5"
    with h5py.File(h5_fn, "r") as f:
        # storms.extend(list(f.keys()))
        # print the keys
        # print(point)
        # [print(storm.decode('utf-8')) for storm in f['Storm Name'][:]]
        # print(f['Storm Name'][:])
        # decode the storm names to string
        storms.extend([storm.decode('utf-8') for storm in f['Storm Name'][:]])

# view storm counts
from collections import Counter
a = dict(Counter(storms))
print (f'Each Storm Name Count should match number of Points = {len(points)}')
print(a)

# remove duplicates
storms = list(set(storms))
# Out:
# Each Storm Name Count should match number of Points = 18
# {'Hugo': 18, 'Andrew': 18, 'Fran': 18, 'Frances': 18, 'Matthew': 18, 'Irma': 18, 'Florence': 18}

# %%
# For each point, get the peak WSE from the CHS HDF5 (.h5) data for each historical storm and save to a dataframe
for point in points:
    storms = []
    peak_wse = []
    h5_fn = f"CHS-SA_TH_SimB1HT_ADCIRC01_Peaks/CHS-SA_TH_SimB1HT_Post0_SP{point}_ADCIRC01_Peaks.h5"
    with h5py.File(h5_fn, "r") as f:
        # get the peak WSE for each storm
        storms.extend([storm.decode('utf-8') for storm in f['Storm Name'][:]])
        peak_wse = f["Water Elevation"][:]
        # print(peak_wse)
        # print(storms)

        # Add the peak WSE for each storm to the geojson
        for feature in data["features"]:
            if feature["properties"]["Point"] == point:
                for i, storm in enumerate(storms):
                    feature["properties"][f'{storm}_wse'] = peak_wse[i]

# Save the geojson with the peak WSE for each storm
with open("CHS ADCIRC Test Points with Peak WSE.geojson", "w") as f:
    json.dump(data, f)

# %% [markdown]
# # The Following table illustrates the CHS peak WSE data pulled for each point for multiple historic events.

# %%
# Geojson to pandas dataframe
import geopandas as gpd
gdf = gpd.read_file("CHS ADCIRC Test Points with Peak WSE.geojson")
gdf
# Out:
#     Point      Hugo_wse    Andrew_wse      Fran_wse   Frances_wse  \
# 0   17393      2.082267      2.173514      1.800435      1.730509
# 1   17502      2.020779      2.117998      1.752374      1.707301
# 2   17808      1.910270      2.009375      1.705437      1.685486
# 3   18090 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 4   18525 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 5   17386      1.355734      1.379408      1.373533      1.467996
# 6   18172 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 7   18413 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 8   17804      0.966477      0.841390      0.958371      1.207413
# 9   17359 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 10  17491 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 11  17824 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 12  18274 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 13  18044 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 14  18015 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 15  18084      1.167256      1.048769      1.152675      1.225181
# 16  17999 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 17  18107      1.172820      1.053388      1.157783      1.274820
#
#      Matthew_wse      Irma_wse  Florence_wse                    geometry
# 0       2.467037      2.692735      2.040012  POINT (-81.43500 30.52300)
# 1       2.577516      2.704891      1.994340  POINT (-81.41100 30.46000)
# 2       2.636136      2.660179      1.878746  POINT (-81.39700 30.36400)
# 3       2.749486      2.712674 -99999.000000  POINT (-81.38580 30.27030)
# 4  -99999.000000 -99999.000000 -99999.000000  POINT (-81.46500 30.12600)
# 5       2.287906      2.471192      1.467594  POINT (-81.49400 30.52500)
# 6  -99999.000000 -99999.000000 -99999.000000  POINT (-81.50500 30.24500)
# 7  -99999.000000 -99999.000000 -99999.000000  POINT (-81.61710 30.15870)
# 8       1.582741      2.046001      1.034894  POINT (-81.61300 30.36500)
# 9  -99999.000000 -99999.000000 -99999.000000  POINT (-81.62400 30.53800)
# 10 -99999.000000 -99999.000000 -99999.000000  POINT (-81.79600 30.47000)
# 11 -99999.000000 -99999.000000 -99999.000000  POINT (-81.78300 30.35800)
# 12 -99999.000000 -99999.000000 -99999.000000  POINT (-81.78110 30.21300)
# 13      2.750063      2.718491 -99999.000000  POINT (-81.38920 30.28430)
# 14 -99999.000000 -99999.000000 -99999.000000  POINT (-81.39830 30.29570)
# 15      1.978545      1.870136      1.217775  POINT (-81.40920 30.27200)
# 16 -99999.000000 -99999.000000 -99999.000000  POINT (-81.39280 30.30050)
# 17      1.994416      1.953627      1.220706  POINT (-81.42400 30.26600)

# %%
# Drop points with noData
gdf = gdf[gdf.Hugo_wse != -99999.0]

# Create geojson with onlly valid data points
gdf.to_file("CHS ADCIRC Test Points with Peak WSE (no missing data).geojson", driver='GeoJSON')

gdf
# Out:
#     Point  Hugo_wse  Andrew_wse  Fran_wse  Frances_wse  Matthew_wse  Irma_wse  \
# 0   17393  2.082267    2.173514  1.800435     1.730509     2.467037  2.692735
# 1   17502  2.020779    2.117998  1.752374     1.707301     2.577516  2.704891
# 2   17808  1.910270    2.009375  1.705437     1.685486     2.636136  2.660179
# 5   17386  1.355734    1.379408  1.373533     1.467996     2.287906  2.471192
# 8   17804  0.966477    0.841390  0.958371     1.207413     1.582741  2.046001
# 15  18084  1.167256    1.048769  1.152675     1.225181     1.978545  1.870136
# 17  18107  1.172820    1.053388  1.157783     1.274820     1.994416  1.953627
#
#     Florence_wse                    geometry
# 0       2.040012  POINT (-81.43500 30.52300)
# 1       1.994340  POINT (-81.41100 30.46000)
# 2       1.878746  POINT (-81.39700 30.36400)
# 5       1.467594  POINT (-81.49400 30.52500)
# 8       1.034894  POINT (-81.61300 30.36500)
# 15      1.217775  POINT (-81.40920 30.27200)
# 17      1.220706  POINT (-81.42400 30.26600)

# %%
# Create a folium map with the geojson containing the peak WSE for each storm.
# The map will have a slider to show the peak WSE for each storm.
# The map will have a legend to show the color scale for the peak WSE.
import folium
from folium.features import DivIcon


geojson_fn = "CHS ADCIRC Test Points with Peak WSE (no missing data).geojson"
fields=[
                "Point",
				"Hugo_wse",
				"Andrew_wse",
				"Fran_wse",
				"Frances_wse",
				"Matthew_wse",
				"Irma_wse",
				"Florence_wse"
            ]
m = folium.Map(location=[30.3322, -81.6557], tiles="CartoDB Positron", zoom_start=10)

tooltip = folium.GeoJsonTooltip(
    fields=fields,
    localize=True,
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
        fill-opacity: 0.1;
    """,
    max_width=800,
    opacity=0.5,
)

popup = folium.GeoJsonPopup(
    fields=fields,
    # aliases=["ADCIRC Point"],
    localize=True,
    labels=True,
    style="""
        border: 0px solid black;
        border-radius: 1px;
        box-shadow: 1px;
    """,
    opacity=0.5,
    
)

folium.GeoJson(
    geojson_fn,
    tooltip=tooltip,
    popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3f0709487b7806e3b2cf172611bc466 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#         background-color: #F0EFEF;
#         border: 2px solid black;
#         border-radius: 3px;
#         box-shadow: 3px;
#         fill-opacity: 0.1;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#
#         border: 0px solid black;
#         border-radius: 1px;
#         box-shadow: 1px;
#
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3f0709487b7806e3b2cf172611bc466&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3f0709487b7806e3b2cf172611bc466 = L.map(
#                 &quot;map_f3f0709487b7806e3b2cf172611bc466&quot;,
#                 {
#                     center: [30.3322, -81.6557],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e656cadc3c6ab23c278b724e6d24449f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f3f0709487b7806e3b2cf172611bc466);
#
#
#
#         function geo_json_1b769f2c3be686341d35a1dec7071a21_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1b769f2c3be686341d35a1dec7071a21 = L.geoJson(null, {
#                 onEachFeature: geo_json_1b769f2c3be686341d35a1dec7071a21_onEachFeature,
#
#         });
#
#         function geo_json_1b769f2c3be686341d35a1dec7071a21_add (data) {
#             geo_json_1b769f2c3be686341d35a1dec7071a21
#                 .addData(data)
#                 .addTo(map_f3f0709487b7806e3b2cf172611bc466);
#         }
#             geo_json_1b769f2c3be686341d35a1dec7071a21_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.435, 30.523], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Andrew_wse&quot;: 2.1735139278, &quot;Florence_wse&quot;: 2.0400117245, &quot;Fran_wse&quot;: 1.8004349962, &quot;Frances_wse&quot;: 1.7305086295, &quot;Hugo_wse&quot;: 2.0822665301, &quot;Irma_wse&quot;: 2.6927346029, &quot;Matthew_wse&quot;: 2.4670365021, &quot;Point&quot;: 17393}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.411, 30.46], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Andrew_wse&quot;: 2.1179984443, &quot;Florence_wse&quot;: 1.9943403878, &quot;Fran_wse&quot;: 1.752374106, &quot;Frances_wse&quot;: 1.7073009863, &quot;Hugo_wse&quot;: 2.0207791561, &quot;Irma_wse&quot;: 2.7048908476, &quot;Matthew_wse&quot;: 2.577515914, &quot;Point&quot;: 17502}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.397, 30.364], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Andrew_wse&quot;: 2.0093746991, &quot;Florence_wse&quot;: 1.8787460212, &quot;Fran_wse&quot;: 1.7054372782, &quot;Frances_wse&quot;: 1.685485898, &quot;Hugo_wse&quot;: 1.9102700152, &quot;Irma_wse&quot;: 2.6601787103, &quot;Matthew_wse&quot;: 2.6361356775, &quot;Point&quot;: 17808}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-81.494, 30.525], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;Andrew_wse&quot;: 1.3794076604, &quot;Florence_wse&quot;: 1.4675941578, &quot;Fran_wse&quot;: 1.3735328807, &quot;Frances_wse&quot;: 1.4679955761, &quot;Hugo_wse&quot;: 1.3557342207, &quot;Irma_wse&quot;: 2.4711918016, &quot;Matthew_wse&quot;: 2.2879062777, &quot;Point&quot;: 17386}, &quot;
